# %% [markdown]
# # 01 - Download Weather Data

# %%
import sys
# !{sys.executable} -m pip install meteostat
# Out:
# Requirement already satisfied: meteostat in d:\anaconda\envs\myenv\lib\site-packages (1.7.4)
# Requirement already satisfied: pandas>=2 in d:\anaconda\envs\myenv\lib\site-packages (from meteostat) (2.3.1)
# Requirement already satisfied: pytz in d:\anaconda\envs\myenv\lib\site-packages (from meteostat) (2025.2)
# Requirement already satisfied: numpy in d:\anaconda\envs\myenv\lib\site-packages (from meteostat) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\myenv\lib\site-packages (from pandas>=2->meteostat) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\myenv\lib\site-packages (from pandas>=2->meteostat) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2->meteostat) (1.17.0)

# %%
import pandas as pd
from datetime import datetime
from meteostat import Point, Daily

# %%
madrid = Point(40.4168, -3.7038, 667)

# %%
start = datetime(2010, 1, 1)
end = datetime(2020, 12, 31)

# %%
data = Daily(madrid, start, end)
data = data.fetch()
data
# Out:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  tsun
# time
# 2010-01-01   5.3   3.5   7.5   0.1  <NA>  <NA>  27.2  <NA>  1010.7  <NA>
# 2010-01-02   5.4   2.5   7.4   0.0  <NA>  <NA>   7.0  <NA>  1020.8  <NA>
# 2010-01-03   5.7   4.1   7.3   6.7  <NA>  <NA>   2.7  <NA>  1019.3  <NA>
# 2010-01-04   7.5   6.3   9.1   9.5  <NA>  <NA>   8.1  <NA>  1008.3  <NA>
# 2010-01-05   8.5   6.1   9.7   0.0  <NA>  <NA>   3.8  <NA>  1001.4  <NA>
# ...          ...   ...   ...   ...   ...   ...   ...   ...     ...   ...
# 2020-12-27   2.3  -1.4   6.8   2.2  <NA>  <NA>  13.4  <NA>  1014.5  <NA>
# 2020-12-28   5.9   2.8   8.4   0.1  <NA>  <NA>  28.8  <NA>  1002.2  <NA>
# 2020-12-29   3.5   0.7   8.1   0.0  <NA>  <NA>  19.0  <NA>  1006.1  <NA>
# 2020-12-30   3.7   1.1   8.3   0.0  <NA>  <NA>  15.1  <NA>  1015.9  <NA>
# 2020-12-31   2.9  -1.3   6.8   1.0  <NA>  <NA>  14.9  <NA>  1014.4  <NA>
#
# [4018 rows x 10 columns]

# %%
data.to_csv("../data/raw/madrid_weather_2010-2022.csv", index=True)
